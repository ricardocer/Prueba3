# %% [markdown]
# # III. Gestión de datos avanzada

# %% [markdown]
# ## Correlaciones. Entender las relaciones entre las variables
#
# Sean $X$ e $Y$ variables aleatorias i.i.d., y sea $\rho_{X,Y}$ la correlación entre $X$ e $Y$.
#
# Se considera **correlación baja** para $\thinspace  \rho_{X,Y} \in [-0.3,0.3]$
#
# Se considera **correlación fuerte** para $\thinspace \rho_{X,Y} \in [-1,-0.6] \cup [0.6,1] $
#
# En este ejemplo se analizan dos variables: ***Hora de Salida (DepDelay)*** y ***Hora de Arribar (ArrDelay)***. Evidentemente, la hora de salida afecta la hora de llegada. Observe la variable de correlación ($Matriz_correlación[0,1]$).

# %%
import pandas as pd
import numpy as np

n = 10**6
df = pd.read_csv(r"C:\COVID_pruebas\base_datos_2008.csv", nrows=n )

# %%
matriz_correlaciones = np.corrcoef( df["ArrDelay"], df["DepDelay"] )
matriz_correlaciones
#Esto me da un error pues recordemos que hay vacíos en el df original.
# Hay que limpiar esos datos faltantes
# Out:
# array([[nan, nan],
#        [nan, nan]])

# %%
df.dropna( inplace=True, subset=["ArrDelay","DepDelay"] )
#inplace mantiene los datos de entrada en la misma variable.
# No hay necesidad de guardar los resultados en otro df, ya se "Actualizaron"
# Corremos nuevamente la matriz de correlaciones

# %%
matriz_correlaciones = np.corrcoef( df["ArrDelay"], df["DepDelay"] )
matriz_correlaciones
#Esto me da un error pues recordemos que hay vacíos en el df original.
# Hay que limpiar esos datos faltantes
# Out:
# array([[1.        , 0.93490112],
#        [0.93490112, 1.        ]])

# %% [markdown]
# **Nota:** Es posible agregar más variables aleatorias al análisis. Tome ***Hora de Salida ("Deptime")***.

# %%
matriz_correlaciones_2 = np.corrcoef([ df["ArrDelay"], df["DepDelay"], df["DepTime"] ])
matriz_correlaciones_2
#Se observa que la nueva correlación es más débil, en comparación con la anterior
# Out:
# array([[1.        , 0.93490112, 0.17978801],
#        [0.93490112, 1.        , 0.21229661],
#        [0.17978801, 0.21229661, 1.        ]])

# %%
df.drop(inplace=True, columns=["Year","Cancelled","Diverted"])

#Se eliminan variables constantes o dummies.

# %%
df.corr()
#Matriz de correlaciones
# Out:
#                       Month  DayofMonth  DayOfWeek   DepTime  CRSDepTime  \
# Month              1.000000   -0.015050   0.030930  0.005771    0.001497
# DayofMonth        -0.015050    1.000000  -0.051893 -0.004149   -0.002338
# DayOfWeek          0.030930   -0.051893   1.000000  0.006505    0.010266
# DepTime            0.005771   -0.004149   0.006505  1.000000    0.967093
# CRSDepTime         0.001497   -0.002338   0.010266  0.967093    1.000000
# ArrTime           -0.007122    0.001970   0.005845  0.718832    0.701446
# CRSArrTime        -0.009800   -0.000563   0.007485  0.801405    0.800630
# FlightNum          0.079810   -0.005089  -0.003372 -0.001497   -0.013377
# ActualElapsedTime -0.074488    0.009748   0.005525 -0.033971   -0.031518
# CRSElapsedTime    -0.076087    0.005772   0.012497 -0.025449   -0.020645
# AirTime           -0.069707    0.007797   0.009195 -0.031907   -0.027183
# ArrDelay           0.031751   -0.016971  -0.020013  0.179788    0.102853
# DepDelay           0.032285   -0.025893  -0.009137  0.212297    0.132519
# Distance          -0.070562    0.004336   0.013937 -0.021899   -0.014220
# TaxiIn            -0.039301   -0.013975   0.007376 -0.028305   -0.032370
# TaxiOut           -0.028302    0.020010  -0.023813 -0.007641   -0.018797
# CarrierDelay      -0.007918   -0.026833   0.011215  0.013935   -0.046834
# WeatherDelay       0.023720    0.002860  -0.004178  0.004591   -0.022649
# NASDelay          -0.018685    0.046824  -0.051235 -0.031814   -0.074218
# SecurityDelay     -0.000285   -0.018356   0.008752 -0.008924   -0.009042
# LateAircraftDelay  0.035021   -0.010162  -0.002767  0.219831    0.187314
#
#                     ArrTime  CRSArrTime  FlightNum  ActualElapsedTime  \
# Month             -0.007122   -0.009800   0.079810          -0.074488
# DayofMonth         0.001970   -0.000563  -0.005089           0.009748
# DayOfWeek          0.005845    0.007485  -0.003372           0.005525
# DepTime            0.718832    0.801405  -0.001497          -0.033971
# CRSDepTime         0.701446    0.800630  -0.013377          -0.031518
# ArrTime            1.000000    0.857240  -0.011925           0.027351
# CRSArrTime         0.857240    1.000000  -0.025392           0.036679
# FlightNum         -0.011925   -0.025392   1.000000          -0.289356
# ActualElapsedTime  0.027351    0.036679  -0.289356           1.000000
# CRSElapsedTime     0.031429    0.047353  -0.302250           0.977603
# AirTime            0.026009    0.038180  -0.314668           0.983909
# ArrDelay           0.073489    0.098478   0.068460           0.062966
# DepDelay           0.087577    0.126896   0.053206           0.020822
# Distance           0.026093    0.044240  -0.333416           0.956349
# TaxiIn             0.009363   -0.002497   0.023670           0.158391
# TaxiOut            0.010162    0.000617   0.073521           0.256360
# CarrierDelay      -0.044245   -0.047146   0.094233          -0.044983
# WeatherDelay      -0.018817   -0.018615   0.066190          -0.010370
# NASDelay           0.016260   -0.048304   0.010670           0.188094
# SecurityDelay     -0.004983   -0.008037  -0.006524          -0.001425
# LateAircraftDelay  0.014447    0.161782  -0.021083          -0.091541
#
#                    CRSElapsedTime  ...  ArrDelay  DepDelay  Distance  \
# Month                   -0.076087  ...  0.031751  0.032285 -0.070562
# DayofMonth               0.005772  ... -0.016971 -0.025893  0.004336
# DayOfWeek                0.012497  ... -0.020013 -0.009137  0.013937
# DepTime                 -0.025449  ...  0.179788  0.212297 -0.021899
# CRSDepTime              -0.020645  ...  0.102853  0.132519 -0.014220
# ArrTime                  0.031429  ...  0.073489  0.087577  0.026093
# CRSArrTime               0.047353  ...  0.098478  0.126896  0.044240
# FlightNum               -0.302250  ...  0.068460  0.053206 -0.333416
# ActualElapsedTime        0.977603  ...  0.062966  0.020822  0.956349
# CRSElapsedTime           1.000000  ... -0.022951  0.009131  0.978077
# AirTime                  0.987368  ...  0.004612  0.004522  0.975308
# ArrDelay                -0.022951  ...  1.000000  0.934901 -0.026296
# DepDelay                 0.009131  ...  0.934901  1.000000  0.004399
# Distance                 0.978077  ... -0.026296  0.004399  1.000000
# TaxiIn                   0.099275  ...  0.118424  0.020033  0.070510
# TaxiOut                  0.123392  ...  0.309567  0.092959  0.076459
# CarrierDelay            -0.010326  ...  0.476940  0.506839 -0.009092
# WeatherDelay            -0.024111  ...  0.279551  0.255680 -0.028149
# NASDelay                 0.046358  ...  0.357162  0.167083  0.018185
# SecurityDelay            0.001212  ... -0.006260 -0.002860  0.002166
# LateAircraftDelay       -0.046930  ...  0.507945  0.551564 -0.035306
#
#                      TaxiIn   TaxiOut  CarrierDelay  WeatherDelay  NASDelay  \
# Month             -0.039301 -0.028302     -0.007918      0.023720 -0.018685
# DayofMonth        -0.013975  0.020010     -0.026833      0.002860  0.046824
# DayOfWeek          0.007376 -0.023813      0.011215     -0.004178 -0.051235
# DepTime           -0.028305 -0.007641      0.013935      0.004591 -0.031814
# CRSDepTime        -0.032370 -0.018797     -0.046834     -0.022649 -0.074218
# ArrTime            0.009363  0.010162     -0.044245     -0.018817  0.016260
# CRSArrTime        -0.002497  0.000617     -0.047146     -0.018615 -0.048304
# FlightNum          0.023670  0.073521      0.094233      0.066190  0.010670
# ActualElapsedTime  0.158391  0.256360     -0.044983     -0.010370  0.188094
# CRSElapsedTime     0.099275  0.123392     -0.010326     -0.024111  0.046358
# AirTime            0.082392  0.094641     -0.028101     -0.027663  0.075806
# ArrDelay           0.118424  0.309567      0.476940      0.279551  0.357162
# DepDelay           0.020033  0.092959      0.506839      0.255680  0.167083
# Distance           0.070510  0.076459     -0.009092     -0.028149  0.018185
# TaxiIn             1.000000  0.048334     -0.042360      0.006748  0.199826
# TaxiOut            0.048334  1.000000     -0.060460      0.064435  0.410929
# CarrierDelay      -0.042360 -0.060460      1.000000     -0.059067 -0.139575
# WeatherDelay       0.006748  0.064435     -0.059067      1.000000 -0.018083
# NASDelay           0.199826  0.410929     -0.139575     -0.018083  1.000000
# SecurityDelay     -0.007527 -0.009747     -0.019080     -0.007717 -0.017256
# LateAircraftDelay -0.046949 -0.108578     -0.155135     -0.049814 -0.150310
#
#                    SecurityDelay  LateAircraftDelay
# Month                  -0.000285           0.035021
# DayofMonth             -0.018356          -0.010162
# DayOfWeek               0.008752          -0.002767
# DepTime                -0.008924           0.219831
# CRSDepTime             -0.009042           0.187314
# ArrTime                -0.004983           0.014447
# CRSArrTime             -0.008037           0.161782
# FlightNum              -0.006524          -0.021083
# ActualElapsedTime      -0.001425          -0.091541
# CRSElapsedTime          0.001212          -0.046930
# AirTime                 0.001673          -0.064661
# ArrDelay               -0.006260           0.507945
# DepDelay               -0.002860           0.551564
# Distance                0.002166          -0.035306
# TaxiIn                 -0.007527          -0.046949
# TaxiOut                -0.009747          -0.108578
# CarrierDelay           -0.019080          -0.155135
# WeatherDelay           -0.007717          -0.049814
# NASDelay               -0.017256          -0.150310
# SecurityDelay           1.000000          -0.016765
# LateAircraftDelay      -0.016765           1.000000
#
# [21 rows x 21 columns]

# %%
df.drop(inplace=True, columns=["Month"])
matriz = round( df.corr(),2 )
matriz.style.background_gradient()
# Out:
# <style type="text/css">
# #T_cdda2_row0_col0, #T_cdda2_row1_col1, #T_cdda2_row2_col2, #T_cdda2_row3_col3, #T_cdda2_row4_col4, #T_cdda2_row5_col5, #T_cdda2_row6_col6, #T_cdda2_row7_col7, #T_cdda2_row8_col8, #T_cdda2_row9_col9, #T_cdda2_row10_col10, #T_cdda2_row11_col11, #T_cdda2_row12_col12, #T_cdda2_row13_col13, #T_cdda2_row14_col14, #T_cdda2_row15_col15, #T_cdda2_row16_col16, #T_cdda2_row17_col17, #T_cdda2_row18_col18, #T_cdda2_row19_col19 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_cdda2_row0_col1, #T_cdda2_row0_col11, #T_cdda2_row0_col18, #T_cdda2_row1_col0, #T_cdda2_row6_col7, #T_cdda2_row6_col8, #T_cdda2_row6_col9, #T_cdda2_row6_col12, #T_cdda2_row7_col2, #T_cdda2_row8_col2, #T_cdda2_row9_col2, #T_cdda2_row12_col6, #T_cdda2_row12_col10, #T_cdda2_row13_col2, #T_cdda2_row15_col4, #T_cdda2_row15_col5, #T_cdda2_row15_col16, #T_cdda2_row15_col18, #T_cdda2_row15_col19, #T_cdda2_row17_col1, #T_cdda2_row17_col2, #T_cdda2_row17_col3, #T_cdda2_row17_col5, #T_cdda2_row17_col18, #T_cdda2_row19_col13, #T_cdda2_row19_col14, #T_cdda2_row19_col15, #T_cdda2_row19_col17, #T_cdda2_row19_col18 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_cdda2_row0_col2, #T_cdda2_row1_col18, #T_cdda2_row6_col2, #T_cdda2_row6_col4, #T_cdda2_row7_col6, #T_cdda2_row9_col10, #T_cdda2_row9_col11, #T_cdda2_row9_col16, #T_cdda2_row10_col0, #T_cdda2_row10_col1, #T_cdda2_row12_col11, #T_cdda2_row12_col16, #T_cdda2_row14_col1, #T_cdda2_row16_col2, #T_cdda2_row16_col5, #T_cdda2_row18_col0, #T_cdda2_row18_col11 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_cdda2_row0_col3, #T_cdda2_row13_col16 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_cdda2_row0_col4, #T_cdda2_row0_col13, #T_cdda2_row1_col2, #T_cdda2_row3_col16, #T_cdda2_row4_col16, #T_cdda2_row5_col16, #T_cdda2_row6_col0, #T_cdda2_row7_col3, #T_cdda2_row8_col11, #T_cdda2_row8_col16, #T_cdda2_row9_col3, #T_cdda2_row11_col1, #T_cdda2_row13_col0, #T_cdda2_row13_col3, #T_cdda2_row15_col2, #T_cdda2_row17_col16, #T_cdda2_row18_col4, #T_cdda2_row18_col5, #T_cdda2_row18_col13, #T_cdda2_row19_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_cdda2_row0_col5, #T_cdda2_row1_col4, #T_cdda2_row2_col0, #T_cdda2_row3_col0, #T_cdda2_row4_col0, #T_cdda2_row5_col0, #T_cdda2_row5_col13, #T_cdda2_row6_col1, #T_cdda2_row7_col11, #T_cdda2_row7_col16, #T_cdda2_row8_col3, #T_cdda2_row12_col0, #T_cdda2_row13_col4, #T_cdda2_row13_col5, #T_cdda2_row13_col11, #T_cdda2_row14_col3, #T_cdda2_row14_col4, #T_cdda2_row14_col5, #T_cdda2_row14_col19, #T_cdda2_row15_col14, #T_cdda2_row16_col0, #T_cdda2_row16_col1, #T_cdda2_row16_col3, #T_cdda2_row18_col16, #T_cdda2_row19_col1, #T_cdda2_row19_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_cdda2_row0_col6, #T_cdda2_row0_col8, #T_cdda2_row1_col8, #T_cdda2_row3_col6, #T_cdda2_row3_col12, #T_cdda2_row4_col6, #T_cdda2_row11_col7, #T_cdda2_row11_col8, #T_cdda2_row15_col12, #T_cdda2_row18_col6 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_cdda2_row0_col7, #T_cdda2_row1_col7, #T_cdda2_row2_col11, #T_cdda2_row2_col12, #T_cdda2_row11_col2, #T_cdda2_row18_col8, #T_cdda2_row19_col6 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_cdda2_row0_col9, #T_cdda2_row1_col9, #T_cdda2_row19_col2, #T_cdda2_row19_col3 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_cdda2_row0_col10, #T_cdda2_row1_col10, #T_cdda2_row2_col18, #T_cdda2_row3_col18, #T_cdda2_row5_col18, #T_cdda2_row6_col18, #T_cdda2_row8_col10, #T_cdda2_row10_col18, #T_cdda2_row12_col2, #T_cdda2_row13_col18, #T_cdda2_row14_col18, #T_cdda2_row15_col13, #T_cdda2_row15_col17, #T_cdda2_row16_col18, #T_cdda2_row17_col19, #T_cdda2_row19_col16 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_cdda2_row0_col12, #T_cdda2_row1_col6, #T_cdda2_row2_col6, #T_cdda2_row4_col7, #T_cdda2_row11_col12, #T_cdda2_row18_col12 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_cdda2_row0_col14, #T_cdda2_row4_col11, #T_cdda2_row12_col13, #T_cdda2_row14_col11 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_cdda2_row0_col15, #T_cdda2_row9_col15, #T_cdda2_row14_col16, #T_cdda2_row16_col17, #T_cdda2_row18_col17 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_cdda2_row0_col16, #T_cdda2_row1_col5, #T_cdda2_row1_col13, #T_cdda2_row1_col16, #T_cdda2_row2_col1, #T_cdda2_row2_col16, #T_cdda2_row3_col1, #T_cdda2_row4_col1, #T_cdda2_row4_col13, #T_cdda2_row5_col1, #T_cdda2_row6_col3, #T_cdda2_row7_col0, #T_cdda2_row7_col1, #T_cdda2_row8_col0, #T_cdda2_row8_col1, #T_cdda2_row9_col0, #T_cdda2_row9_col1, #T_cdda2_row12_col1, #T_cdda2_row12_col3, #T_cdda2_row13_col1, #T_cdda2_row15_col1, #T_cdda2_row16_col13, #T_cdda2_row17_col4, #T_cdda2_row18_col1, #T_cdda2_row18_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_cdda2_row0_col17, #T_cdda2_row8_col17 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_cdda2_row0_col19, #T_cdda2_row8_col15, #T_cdda2_row12_col15 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_cdda2_row1_col3, #T_cdda2_row6_col11 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_cdda2_row1_col11, #T_cdda2_row2_col13, #T_cdda2_row3_col13, #T_cdda2_row6_col5, #T_cdda2_row9_col6, #T_cdda2_row11_col0, #T_cdda2_row14_col2, #T_cdda2_row15_col0, #T_cdda2_row15_col3, #T_cdda2_row16_col4, #T_cdda2_row17_col15, #T_cdda2_row18_col2, #T_cdda2_row18_col10 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_cdda2_row1_col12, #T_cdda2_row5_col7, #T_cdda2_row17_col6 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_cdda2_row1_col14, #T_cdda2_row3_col14 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_cdda2_row1_col15, #T_cdda2_row2_col15, #T_cdda2_row4_col17, #T_cdda2_row4_col19, #T_cdda2_row12_col17, #T_cdda2_row13_col10 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_cdda2_row1_col17, #T_cdda2_row5_col17, #T_cdda2_row7_col5, #T_cdda2_row7_col10, #T_cdda2_row9_col5, #T_cdda2_row9_col19, #T_cdda2_row12_col5, #T_cdda2_row14_col15, #T_cdda2_row16_col15 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_cdda2_row1_col19, #T_cdda2_row6_col17 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_cdda2_row2_col3, #T_cdda2_row3_col2, #T_cdda2_row7_col12, #T_cdda2_row12_col7 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_cdda2_row2_col4 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_cdda2_row2_col5, #T_cdda2_row3_col5 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_cdda2_row2_col7, #T_cdda2_row3_col7, #T_cdda2_row7_col13, #T_cdda2_row9_col17, #T_cdda2_row19_col5 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_cdda2_row2_col8, #T_cdda2_row2_col9, #T_cdda2_row3_col9, #T_cdda2_row8_col14, #T_cdda2_row15_col9, #T_cdda2_row16_col9 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_cdda2_row2_col10, #T_cdda2_row10_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_cdda2_row2_col14, #T_cdda2_row18_col14 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_cdda2_row2_col17, #T_cdda2_row4_col15, #T_cdda2_row5_col14, #T_cdda2_row7_col15, #T_cdda2_row12_col19, #T_cdda2_row13_col15 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_cdda2_row2_col19 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_cdda2_row3_col4 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_cdda2_row3_col8, #T_cdda2_row6_col15, #T_cdda2_row10_col8, #T_cdda2_row16_col7, #T_cdda2_row16_col8, #T_cdda2_row19_col12 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_cdda2_row3_col10, #T_cdda2_row5_col10, #T_cdda2_row11_col4 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_cdda2_row3_col11, #T_cdda2_row5_col11, #T_cdda2_row16_col14, #T_cdda2_row19_col7 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_cdda2_row3_col15, #T_cdda2_row4_col10, #T_cdda2_row5_col15, #T_cdda2_row6_col10, #T_cdda2_row8_col5, #T_cdda2_row8_col19, #T_cdda2_row13_col19, #T_cdda2_row14_col13, #T_cdda2_row16_col19, #T_cdda2_row17_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_cdda2_row3_col17, #T_cdda2_row6_col13, #T_cdda2_row7_col4, #T_cdda2_row8_col4, #T_cdda2_row9_col4, #T_cdda2_row11_col13, #T_cdda2_row1

# %% [markdown]
# ## Test de la Chi-Cuadrado
#
# La prueba de ji cuadrado se usa para comprobar hipótesis sobre si ciertos datos son como se esperaba. La idea clave tras la prueba es comparar los valores observados en los datos con los valores esperados que tendríamos si la hipótesis nula es cierta. Esto se aplica a **variables cualitativas**
#
# $$\chi^{2} = \sum_{i=1}^{k} \dfrac{(observado_{i} - esperado_{i})^{2}}{esperado_i} $$
#
#
# Una **debilidad** de este test es que no podemos cuantificar cada una de las relaciones entre categorías; sin embargo permite **afirmaciones globales** del tipo **fumar está relacionado significativamente con el cáncer de pulmón**.

# %%
import pandas as pd
import numpy as np

n = 10**6
df = pd.read_csv(r"C:\COVID_pruebas\base_datos_2008.csv")

# %%
print("Las dimensiones son: ",df.shape)
df.head(2)
# Out:
# Las dimensiones son:  (7009728, 29)
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0               NaN         0           NaN          NaN      NaN
# 1               NaN         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
# 1            NaN                NaN
#
# [2 rows x 29 columns]

# %% [markdown]
# **Observación:** En comparación con otros scripts, se importó la base completa, misma que tiene 7,009,728 registros.

# %%
np.random.seed(0)
#Esto fija una semilla

df_1 = df[ df["Origin"].isin( ["HOU","ATL","IND"] ) ]
#Se seleccionan los vuelos que tienen como orígen a HOU,ATL,IND

df_1 = df_1.sample( frac=1 )
#Se reordenan de manera "aleatoria" los datos que se tienen 

df_muestra = df_1[0:10000]
#Se toma una muestra de 10,000 registros

# %%
df_muestra["BigDelay"] = df_muestra["ArrDelay"] > 30
#Si "ArrDelay">30, colocará un "True". En caso contrario, colocará un "False"

observados = pd.crosstab( index=df_muestra["BigDelay"], columns=df_muestra["Origin"], margins=True )
#Esto genera una tabla de contingencia.
# Se estudian dos columnas: "BigDelay" y "Origin"
# Margins indica que se guarden los márgenes en la tabla (las sumas de los totales)
# Out:
# C:\Users\ricar\AppData\Local\Temp/ipykernel_1132/237617485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_muestra["BigDelay"] = df_muestra["ArrDelay"] > 30

# %%
observados
# Out:
# Origin     ATL   HOU  IND    All
# BigDelay
# False     6927   883  765   8575
# True      1197   129   99   1425
# All       8124  1012  864  10000

# %% [markdown]
# Esta **Tabla de contingencia** se interpreta de la siguiente manera:
#
# La cantidad de vuelos que salieron de ***Atl*** y se retrasaron ***menos*** de 30 min., fue de 6,927.
#
# La cantidad de vuelos que salieron de ***Atl*** y se retrasaron ***más*** de 30 min., fue de 6,927
#
# ***El total*** de vuelos que salieron de ***Atl*** con retraso, fue de 8124

# %%
from scipy.stats import chi2_contingency
#Este paquete se encarga de realizar el test

test = chi2_contingency(observados)
#Genera el objeto a partir de la tabla de observados
test
# Out:
# (8.939538453043031,
#  0.17700704816414425,
#  6,
#  array([[ 6966.33,   867.79,   740.88,  8575.  ],
#         [ 1157.67,   144.21,   123.12,  1425.  ],
#         [ 8124.  ,  1012.  ,   864.  , 10000.  ]]))

# %% [markdown]
# Los **parámetros** que retorna la **prueba de chi_cuadrado** son:
#
# * Estadístico de prueba
# * p-valor
# * Grados de libertad
# * Tabla de las frecuencias esperadas, basadas en las sumas marginales de la tabla. (valores teóricos esperados)

# %%
esperados = pd.DataFrame(test[3])
#Me arroja la matriz de las frecuencias esperadas. (4to parámetro de retorno de test)

esperados
# Out:
#          0        1       2        3
# 0  6966.33   867.79  740.88   8575.0
# 1  1157.67   144.21  123.12   1425.0
# 2  8124.00  1012.00  864.00  10000.0

# %%
esperados_rel = round( esperados.apply (lambda r: (r/len(df_muestra)) *100, axis=1) , 2 )

observados_rel =  round( observados.apply (lambda r: (r/len(df_muestra)) *100, axis=1) , 2 )

#Lambda es una función sin nombre.

# %%
observados_rel
# Out:
# Origin      ATL    HOU   IND     All
# BigDelay
# False     69.27   8.83  7.65   85.75
# True      11.97   1.29  0.99   14.25
# All       81.24  10.12  8.64  100.00

# %%
esperados_rel
# Out:
#        0      1     2       3
# 0  69.66   8.68  7.41   85.75
# 1  11.58   1.44  1.23   14.25
# 2  81.24  10.12  8.64  100.00

# %% [markdown]
# A pesar de que no se copian los nombres de las columnas, **la estructura se mantiene**. Así, es más fácil visualizar la diferencia entre tablas.
#
# **Comentarios:**
# * Los márgenes se mantienen. **Esto siempre debe de ocurrir**.
# * Se compara entrada con entrada para determinar si la diferencia entre éstas es significativa

# %%
test[1]
# Out:
# 0.17700704816414425

# %% [markdown]
# ### Resumen de Test de Hipótesis
# * **p-valor < 0.05:** hay diferencias significativas: Hay relación entre variables
# * **p-valor > 0.05:** no hay diferencias significativas: No hay relación entre variables

# %% [markdown]
# **Conclusiones:** Dado que $p-valor>>0.05$, no es posible afirmar que hay una relación entre variables
